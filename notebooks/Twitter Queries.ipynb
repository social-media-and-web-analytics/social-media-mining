# %% [markdown]
# First insert your bearer token, assuming you have already tested it works in the 'Twitter.ipynb' notebook.

# %%
import tweepy
BEARER_TOKEN = 'AAAAAAAAAAAAAAAAAAAAAIY5lAEAAAAAL9eFnWiMwETdM5GkWuiDwe7OF9U%3Duuzn7eAKn6SueOLHNEwUWhEMJaSB5mULEnk0K3Rg0SGh7evmOK'
client = tweepy.Client(BEARER_TOKEN)

# %% [markdown]
# # Query basics
# Solutions to the exercises below can be found by reading through the [Building queries for Search Tweets](https://developer.twitter.com/en/docs/twitter-api/tweets/search/integrate/build-a-query) documentation.
#
# ## Exercise 01
# Update the `query` variable in the code below to search for recent tweets that contain the word "twitter" and the word "data".

# %%
query = 'twitter data'
tweets = client.search_recent_tweets(query=query, max_results=10)
for tweet in tweets.data:
    print('--- New tweet ---\n')
    print(tweet.text)
    print('\n')
# Out:
# --- New tweet ---
#
# RT @adilsonesp: FRIGORÍFICO DEMITE 800 FUNCIONÁRIOS, E ENCERRA ATIVIDADES DE ABATES EM PAIÇANDU NO PARANÁ
# Frigorífico Big Boi encerrou sua…
#
#
# --- New tweet ---
#
# RT @Fatima__Kay: Fun fact: taking a picture of a person, where the person is the main subject, without permission is illegal in Germany.
#
# Y…
#
#
# --- New tweet ---
#
# RT @MachoDrag: lookin at ur save data on the PS2
#
#
# --- New tweet ---
#
# Zenith bank na thief the don colobi my 4million-Chiamaka Jennifer @a_ma_ka__  @cenbank
#
# https://t.co/7JnCm1MTLi. https://t.co/vy9jwxOkeL
#
#
# --- New tweet ---
#
# #InterIngenieríaYArquitectura abre sede en Francia, diversifica negocio adentrándose en el sector de los data center, y confirma que ampliará la plantilla con talento senior hasta alcanzar los 60 empleados superando los 3M€ en facturación. #ClubCámara https://t.co/o8kCQN314A https://t.co/q8jXuyxUly
#
#
# --- New tweet ---
#
# RT @YahooFinance: December’s year-over-year CPI data matched expectations at 6.5% while dropping 0.1% month-over-month. https://t.co/Dh0D7N…
#
#
# --- New tweet ---
#
# RT @MatthewWielicki: This was never about saving the planet or people. This was always about money and power. In fact, the UN Office of Dis…
#
#
# --- New tweet ---
#
# Welcome to the #TetraPartner Network @labforward  and @SBungers!
#
# Read the press release to learn how our partnership enables scientists to maximize the value of their data utilizing the Tetra Scientific Data Cloud™. https://t.co/Phye8E95I5
#
# #scientificdata @datamanagement https://t.co/7vCMeXdQnN
#
#
# --- New tweet ---
#
# RT @jsstansel: Asking ONE person to be a
#
# Content creator
# Community manager
# Digital strategist
# Data analyst
# Graphic designer
# Videographer
# W…
#
#
# --- New tweet ---
#
# ian craft built on the Siberian c
# IHERB_Code_is (( FBC7556 )) enjoy_discount_promocode_voucher_coupon_discounts_rewards_offers_perfume_promo_
# nutes later Data left the read https://t.co/9odbrb5bwb

# %% [markdown]
# **Question**: Do all the tweets returned contain the word "twitter" and the word "data"?

# %% [markdown]
# ## Exercise 02
# Update the `query` variable in the code below to search for recent tweets that contain the phrase "twitter data".

# %%
query = '"twitter data"'
tweets = client.search_recent_tweets(query=query, max_results=10)
for tweet in tweets.data:
    print('--- New tweet ---\n')
    print(tweet.text)
    print('\n')
# Out:
# --- New tweet ---
#
# Subject Specific Stream Classification Preprocessing Algorithm for Twitter Data Stream https://t.co/mUtbZQtoTF #UoMresearcher
#
#
# --- New tweet ---
#
# @chosekiei i even clear the twitter data cache regularly and that has hardly helped
#
#
# --- New tweet ---
#
# @your_twitter_data
#
#
# --- New tweet ---
#
# RT @TeritoriNetwork: The recent Twitter data leaks drama proves once again that we need to focus on transparent &amp; decentralized alternative…
#
#
# --- New tweet ---
#
# Quando eu vejo o meme “eh pro meu tcc” eu imagino a citação ABNT dessa pesquisa
#
# @ EM MAIÚSCULO, usuário. Twitter. Data. Acesso em
#
#
# --- New tweet ---
#
# RT @SBRC_Scotland: 📢 Was your email among the 200 million+ email addresses leaked in the #Twitter data breach last week?
#
# Ethical Hacker, @…
#
#
# --- New tweet ---
#
# The latest #twitter #infographic #data! https://t.co/8feY6DQoL6 Thanks to @EvaFoxU @Androidheadline @Statusbrew #twitter #data
#
#
# --- New tweet ---
#
# #Kaspersky's Transatlantic Cable #podcast brings you the latest #cybersecurity news. What's new? 👇
# ✔️ #Twitter data breach
# ✔️ #LoganPaul's CryptoZoo failure
# ✔️ #Silvergate woes
# ✔️ &amp; more!
# Listen now 👇 https://t.co/NeSFVXPsnS
#
#
# --- New tweet ---
#
# #Kaspersky's Transatlantic Cable #podcast brings you the latest #cybersecurity news. What's new? 👇
# ✔️ #Twitter data breach
# ✔️ #LoganPaul's CryptoZoo failure
# ✔️ #Silvergate woes
# ✔️ &amp; more!
# Listen now 👇 https://t.co/6IVCUGo4DP
#
#
# --- New tweet ---
#
# RT @discovertext: Trust Defender
# https://t.co/9CABgU21er
#
# This demo uses Flynn Twitter data from January 2023 to identify and score 82,004…

# %% [markdown]
# **Question**: Do all the tweets returned contain the phrase "twitter data"?

# %% [markdown]
# ## Exercise 03
# Update the `query` variable in the code below to search for recent tweets that include the phrase "Elon Musk".

# %%
query = '"Elon Musk"'
tweets = client.search_recent_tweets(query=query, max_results=10)
for tweet in tweets.data:
    print('--- New tweet ---\n')
    print(tweet.text)
    print('\n')
# Out:
# --- New tweet ---
#
# RT @bunmi_speaks: Fresh out of a 7-day Twitter jail. So what was the point of Elon Musk taking over then? Lol. Anyway, nothing in this worl…
#
#
# --- New tweet ---
#
# Alex Berenson has been frequently and flagrantly wrong about the pandemic. https://t.co/lHOe7iGapM # via @HuffPostPol
#
#
# --- New tweet ---
#
# Day 2 of bugging @elonmusk until he answers my question, which he can find pinned to my profile. Yes only he can see it so don't even try:
#
# ELON MUSK MUST ANSWER ME!!!
#
#
# --- New tweet ---
#
# RT @areamilitarof: Ao demitir equipe de monitoramento no Twitter Brasil, Elon Musk reduz a perseguição e a censura na plataforma https://t.…
#
#
# --- New tweet ---
#
# RT @MattWallace888: Elon Musk just called out how the government caused many more deaths than Covid by implementing draconian measures. Can…
#
#
# --- New tweet ---
#
# Our Review Of Quantum Ai Elon Musk Trading App – Is It A Scam? https://t.co/nA369egFMj
#
#
# --- New tweet ---
#
# RT @tuitamarcia: Vocês apoiam que Elon Musk publique os arquivos das eleições Brasileiras??🇧🇷
#
#
# --- New tweet ---
#
# RT @eduardomenoni: Elon Musk despide a todo el personal de Twitter en Brasil, por sesgo de izquierda en las elecciones presidenciales - The…
#
#
# --- New tweet ---
#
# RT @PtAshokkiradoo: @elonmusk Focus on signal over noise don't waste time on stuff that doesn't actually make things better . Elon Musk 💥💥…
#
#
# --- New tweet ---
#
# RT @perspectividade: Vocês apoiam que Elon Musk publique os arquivos das eleições Brasileiras?🇧🇷

# %% [markdown]
# **Question**: Do all the tweets returned contain the phrase "Elon Musk"?

# %% [markdown]
# ## Exercise 04
# Update the `query` variable in the code below to search for recent tweets that include the Twitter handle "@elonmusk" taken from Elon Musk's Twitter [profile page](https://twitter.com/elonmusk/).

# %%
query = '@elonmusk'
tweets = client.search_recent_tweets(query=query, max_results=10)
for tweet in tweets.data:
    print('--- New tweet ---\n')
    print(tweet.text)
    print('\n')
# Out:
# --- New tweet ---
#
# RT @WatcherGuru: @elonmusk CPI fell to 6.5% https://t.co/DrHU0Z3n5I
#
#
# --- New tweet ---
#
# RT @elonmusk: Starship launch attempt soon https://t.co/QBprVsAH7m
#
#
# --- New tweet ---
#
# @swamypmk52 @CNBCTV18News @elonmusk @Twitter It’s gradually rolling out. You should get it soon.
#
#
# --- New tweet ---
#
# RT @P__Crypto: @elonmusk Goatship is ready @elonmusk 🐐 $EGT @ElonGoatToken https://t.co/hOidqqWfng
#
#
# --- New tweet ---
#
# @elonmusk It is incredibly difficult to discern the truth. I think it’s like in any relationship you must look for consistencies or inconsistencies in what someone is saying or doing.
#
#
# --- New tweet ---
#
# @Hobbes63 @AJ40020789 @elonmusk @WOLF_Financial There is a difference between using legal means to challenge or question an and trying to stop a peaceful transfer of power through violence and force.  The MAGA movement lost a LOT of support on 1/6
#
#
# --- New tweet ---
#
# RT @elonmusk: Starship launch attempt soon https://t.co/QBprVsAH7m
#
#
# --- New tweet ---
#
# @elonmusk Like today?
#
#
# --- New tweet ---
#
# @elonmusk Meh…
#
#
# --- New tweet ---
#
# RT @elonmusk: Starship launch attempt soon https://t.co/QBprVsAH7m

# %% [markdown]
# **Question**: How is '@elonmusk' in a Tweet different from "Elon Musk" in a Tweet?
#
# *Hint*: Read about the different types of Tweets [here](https://help.twitter.com/en/using-twitter/types-of-tweets) to understand what "Mentions" are.

# %% [markdown]
# ## Exercise 05
# Write code below to search for recent Tweets that mention @elonmusk and @BillGates.

# %%
# (SOLUTION)
query = '@elonmusk @BillGates'
tweets = client.search_recent_tweets(query=query, max_results=10)
for tweet in tweets.data:
    print('--- New tweet ---\n')
    print(tweet.text)
    print('\n')
# Out:
# --- New tweet ---
#
# Uncle E 👋🏾😏👋🏻🤓 ⁦@BillGates⁩ ⁦@elonmusk⁩ https://t.co/eZiylbpGzx
#
#
# --- New tweet ---
#
# @elonmusk Piss on their grave. @BillGates
#
#
# --- New tweet ---
#
# RT @krawezynski: Inna MODJA : "J'ai subi l'excision mais je revis" https://t.co/FaDe6bKcln
# @FaustineFB @BFMTV_People @BFMTV @FoxNews @CNN…
#
#
# --- New tweet ---
#
# @muum0709 @ponponice420 @cid91951744 @ecoyuri @elonmusk @BillGates @masason すきな子にど畜生しちゃうタイプやん
# 成就せんど♡
#
#
# --- New tweet ---
#
# Inna Modja : "Il faut expliquer pourquoi l’excision est nocive pour le corps des femmes"
# https://t.co/vBlIk4bqJK v
# @FaustineFB @BFMTV_People @BFMTV @FoxNews @CNN @CNEWS @LCI @TwitterFrance @BillGates @MichelleObama @Pontifex_fr @WhiteHouse @TulsiGabbard @elonmusk @Elysee @rihanna
#
#
# --- New tweet ---
#
# @userWaca @ponponice420 @cid91951744 @ecoyuri @elonmusk @BillGates @masason カタワ全般好きやで
# 乙武にこの指止まれとかさせたい
#
#
# --- New tweet ---
#
# @muum0709 @ponponice420 @cid91951744 @ecoyuri @elonmusk @BillGates @masason あんたもうにしくん永久指名しよるやん、すきやん。笑
#
#
# --- New tweet ---
#
# Inna MODJA : "J'ai subi l'excision mais je revis" https://t.co/FaDe6bKcln
# @FaustineFB @BFMTV_People @BFMTV @FoxNews @CNN @CNEWS @LCI @BillGates @MichelleObama @Pontifex_fr @WhiteHouse @TulsiGabbard @elonmusk @Elysee @rihanna @SkyNews @euronews @nbc @nhk_news @FRANCE24 @innamodja
#
#
# --- New tweet ---
#
# L'excision des femmes-Inna Modja. https://t.co/SwEl1Exdtz
# @FaustineFB @BFMTV_People @BFMTV @FoxNews @CNN @CNEWS @LCI @TwitterFrance @BillGates @MichelleObama @Pontifex_fr @WhiteHouse @TulsiGabbard @elonmusk @Elysee @rihanna @SkyNews @euronews @nbc @nhk_news @FRANCE24 @innamodja
#
#
# --- New tweet ---
#
# @userWaca @ponponice420 @cid91951744 @ecoyuri @elonmusk @BillGates @masason お休みなんすね!! https://t.co/Pi7lzpeKTx

# %% [markdown]
# ## Exercise 06
# Write code below to search for recent Tweets that mention @elonmusk and @BillGates and are not retweets.

# %%
# (SOLUTION)
query = '@elonmusk @BillGates -is:retweet'
tweets = client.search_recent_tweets(query=query, max_results=10)
for tweet in tweets.data:
    print('--- New tweet ---\n')
    print(tweet.text)
    print('\n')
# Out:
# --- New tweet ---
#
# Uncle E 👋🏾😏👋🏻🤓 ⁦@BillGates⁩ ⁦@elonmusk⁩ https://t.co/eZiylbpGzx
#
#
# --- New tweet ---
#
# @elonmusk Piss on their grave. @BillGates
#
#
# --- New tweet ---
#
# @muum0709 @ponponice420 @cid91951744 @ecoyuri @elonmusk @BillGates @masason すきな子にど畜生しちゃうタイプやん
# 成就せんど♡
#
#
# --- New tweet ---
#
# Inna Modja : "Il faut expliquer pourquoi l’excision est nocive pour le corps des femmes"
# https://t.co/vBlIk4bqJK v
# @FaustineFB @BFMTV_People @BFMTV @FoxNews @CNN @CNEWS @LCI @TwitterFrance @BillGates @MichelleObama @Pontifex_fr @WhiteHouse @TulsiGabbard @elonmusk @Elysee @rihanna
#
#
# --- New tweet ---
#
# @userWaca @ponponice420 @cid91951744 @ecoyuri @elonmusk @BillGates @masason カタワ全般好きやで
# 乙武にこの指止まれとかさせたい
#
#
# --- New tweet ---
#
# @muum0709 @ponponice420 @cid91951744 @ecoyuri @elonmusk @BillGates @masason あんたもうにしくん永久指名しよるやん、すきやん。笑
#
#
# --- New tweet ---
#
# Inna MODJA : "J'ai subi l'excision mais je revis" https://t.co/FaDe6bKcln
# @FaustineFB @BFMTV_People @BFMTV @FoxNews @CNN @CNEWS @LCI @BillGates @MichelleObama @Pontifex_fr @WhiteHouse @TulsiGabbard @elonmusk @Elysee @rihanna @SkyNews @euronews @nbc @nhk_news @FRANCE24 @innamodja
#
#
# --- New tweet ---
#
# L'excision des femmes-Inna Modja. https://t.co/SwEl1Exdtz
# @FaustineFB @BFMTV_People @BFMTV @FoxNews @CNN @CNEWS @LCI @TwitterFrance @BillGates @MichelleObama @Pontifex_fr @WhiteHouse @TulsiGabbard @elonmusk @Elysee @rihanna @SkyNews @euronews @nbc @nhk_news @FRANCE24 @innamodja
#
#
# --- New tweet ---
#
# @userWaca @ponponice420 @cid91951744 @ecoyuri @elonmusk @BillGates @masason お休みなんすね!! https://t.co/Pi7lzpeKTx
#
#
# --- New tweet ---
#
# I N N A
# M O D J A
# @FaustineFB @BFMTV_People @BFMTV @FoxNews @CNN @CNEWS @LCI @TwitterFrance @BillGates @MichelleObama @Pontifex_fr @WhiteHouse @TulsiGabbard @elonmusk @Elysee @rihanna @SkyNews @euronews @nbc @nhk_news @FRANCE24 @innamodja @Timepieces
# https://t.co/nmjkbM9Rt4

# %% [markdown]
# **Question**: How would you recognise whether a Tweet was a retweet or not?

# %% [markdown]
# ## Exercise 07
# Write code below to search for recent Tweets that are from Elon Musk and are not retweets or replies.

# %%
# (SOLUTION)
query = 'from:elonmusk -is:retweet -is:reply'
tweets = client.search_recent_tweets(query=query, max_results=10)
for tweet in tweets.data:
    print('--- New tweet ---\n')
    print(tweet.text)
    print('\n')
# Out:
# --- New tweet ---
#
# Starship launch attempt soon https://t.co/QBprVsAH7m
#
#
# --- New tweet ---
#
# Some things that your party tells you are false and some things that the other party says are true
#
#
# --- New tweet ---
#
# All four orbital launch pads fully loaded with rockets for the first time! https://t.co/EXlB0p5vWN
#
#
# --- New tweet ---
#
# I hope that the people of Brazil are able to resolve matters peacefully
#
#
# --- New tweet ---
#
# (Chart by James Stephenson) https://t.co/rOHfjXGVmU
#
#
# --- New tweet ---
#
# Easy swipe right/left to move between recommended vs followed tweets rolls out later this week.
#
# First part of a much larger UI overhaul.
#
# Bookmark button (de facto silent like) on Tweet details rolls out a week later.
#
# Long form tweets early Feb.
#
#
# --- New tweet ---
#
# Plaid is sickkk https://t.co/OxBD8Zv7Xq
#
#
# --- New tweet ---
#
# Thread on how safe Tesla cars are https://t.co/M3Hf3q4kh3
#
#
# --- New tweet ---
#
# 8 years later &amp; still no laws … 😢 https://t.co/9fjb24XvFG
#
#
# --- New tweet ---
#
# If I dig my grave deep enough, maybe it comes out other side of Earth 🤔

# %% [markdown]
# # Tweet data
# Solutions to the exercises below can be found by reading through the documentation on the [Tweet object model](https://developer.twitter.com/en/docs/twitter-api/data-dictionary/object-model/tweet).
#
# ## Exercise 08
# Run the code below to search for recent Tweets containing the word "twitter" and to ensure Tweets are returned containing their `id`, `text`, and `created_at` fields.

# %%
query = 'twitter'
fields = [
    'id',
    'text',
    'created_at',
]
tweets = client.search_recent_tweets(query=query, max_results=10,tweet_fields=fields)
for tweet in tweets.data:
    print(f'Tweet ID: {tweet.id}')
    print(f'Created: {tweet.created_at}\n')
    print(tweet.text)
    print('\n')
# Out:
# Tweet ID: 1613547659716968449
# Created: 2023-01-12 14:45:14+00:00
#
# RT @SaudiNews50: الدكتور عبدالله الربيعة:
#
# مرحلة فصل الكبد تعتبر مرحلة حساسة في في عملية فصل التوأم السيامي العراقي "عمر وعلي" كونها مرحلة…
#
#
# Tweet ID: 1613547659712925698
# Created: 2023-01-12 14:45:14+00:00
#
# RT @gukbearbell: สิ่งนี้เคยเกิดขึ้นที่ไทย รอพี่จองกุกใส่แขนสั้นโชว์รอยสักเสยผมแบบนี้ที่ราชมังอีกครั้งอยู่นะคะ
# https://t.co/OQPRNIQds0
#
#
# Tweet ID: 1613547659712921602
# Created: 2023-01-12 14:45:14+00:00
#
# RT @Mvwolk: + 그리고 나는 유지혜 작가님의 패션을 정말 사랑함.. https://t.co/Jj8NybQq9T
#
#
# Tweet ID: 1613547659712921601
# Created: 2023-01-12 14:45:14+00:00
#
# @llandoniffirg Good Morning Griff ☕️😹  Have a marvelous day! https://t.co/y4fqbqTgOi
#
#
# Tweet ID: 1613547659712921600
# Created: 2023-01-12 14:45:14+00:00
#
# RT @TradedogCrypto: Most traded Highlight Memes Tokens last 24h 🖼💥
# 🥇 $QUACK @RichQuack
# 🥈 $VOLT @VoltInuOfficial
# 🥉 $FLOKI @RealFlokiInu
# #BAB…
#
#
# Tweet ID: 1613547659708583937
# Created: 2023-01-12 14:45:14+00:00
#
# Já assisti um pornô que começava assim https://t.co/oWA8SHDMK2
#
#
# Tweet ID: 1613547659708481536
# Created: 2023-01-12 14:45:14+00:00
#
# RT @mirikol333: https://t.co/CaSg95F2Tg
#
#
# Tweet ID: 1613547659704295426
# Created: 2023-01-12 14:45:14+00:00
#
# RT @RNLEE830: Good night 🥺 https://t.co/QwY6FtI7nU
#
#
# Tweet ID: 1613547659704287239
# Created: 2023-01-12 14:45:14+00:00
#
# nunca será caio afiune e rodolfo https://t.co/CyJurzzpPT
#
#
# Tweet ID: 1613547659700342784
# Created: 2023-01-12 14:45:14+00:00
#
# RT @Ecchisama_: Atsuko from Blue Archive
# Artist: @dmvvhv_ver2
# https://t.co/NJllqVhUgE https://t.co/SGYSHCz2vr

# %% [markdown]
# ## Exercise 09
# Update the `fields` variable in the code below to search for recent tweets that contain the word "twitter" and to ensure Tweets are returned containing their `id`, `text`, `created_at`, and `public_metrics` fields.

# %%
query = 'twitter'
#fields = [] # (SOLUTION)
fields = [
    'id',
    'text',
    'created_at',
    'public_metrics',
]

tweets = client.search_recent_tweets(query=query, max_results=10,tweet_fields=fields)
for tweet in tweets.data:
    print(f'Tweet ID: {tweet.id}')
    print(f'Created: {tweet.created_at}\n')
    print(tweet.text)
    print(tweet.public_metrics)
    print('\n')
# Out:
# Tweet ID: 1613549043837472768
# Created: 2023-01-12 14:50:44+00:00
#
# RT @Maria817221291: Dispuesta a complacer al primero que me contacte.  Que esperan?🤤
# OFERTAS MES DE ENERO %50📉
# Waths&gt;&gt;5534607234
# #scort #sc…
# {'retweet_count': 1, 'reply_count': 0, 'like_count': 0, 'quote_count': 0, 'impression_count': 0}
#
#
# Tweet ID: 1613549043837460480
# Created: 2023-01-12 14:50:44+00:00
#
# 💢4X4Rich88
# 💢แตกนอกอุ่นใจ แตกในอุ่นจัง
# ▪️สมาชิกใหม่ ฝาก 40 รับ 100
# ▪️ทำยอดถึง 450 ถอนได้ทันที
# ▪️ลิ้งค์สมัคร https://t.co/2v5wlNwAIp
# ▪️แอดไลน์สมัคร @4X4Rich88
# #ฟรีเครดิต
# #เกมฟรีสปิน
# #เครดิตฟรีล่าสุด
# #สล๊อตเครดิตฟรี
# #เครดิตฟรี50
# #เครดิตฟรีไม่ต้องฝากไม่ต้องแชร์ล่าสุด https://t.co/ff4LvlU5bE
# {'retweet_count': 0, 'reply_count': 0, 'like_count': 0, 'quote_count': 0, 'impression_count': 0}
#
#
# Tweet ID: 1613549043837456384
# Created: 2023-01-12 14:50:44+00:00
#
# RT @Himanshi_mehra_: गर्व से कहो हम हिंदू हैं”
# विश्वभर में भारतीय संस्कृति को स्थापित करने वाले, प्रखर आध्यात्मिक गुरु एवं युवाओं के प्रेर…
# {'retweet_count': 90, 'reply_count': 0, 'like_count': 0, 'quote_count': 0, 'impression_count': 0}
#
#
# Tweet ID: 1613549043837280256
# Created: 2023-01-12 14:50:44+00:00
#
# RT @b_onniiie: J’ai une cette reflexion ce matin..
# L’emploi des senoirs mon cul &amp; mtn pole emploi ne cesse de leur mettre la pression pour…
# {'retweet_count': 1, 'reply_count': 0, 'like_count': 0, 'quote_count': 0, 'impression_count': 0}
#
#
# Tweet ID: 1613549043833278464
# Created: 2023-01-12 14:50:44+00:00
#
# マシロさん
# ありがとうございます🥰🥰🥰🧡🧡🧡 https://t.co/eCS6eGPAo8
# {'retweet_count': 0, 'reply_count': 0, 'like_count': 0, 'quote_count': 0, 'impression_count': 0}
#
#
# Tweet ID: 1613549043833253888
# Created: 2023-01-12 14:50:44+00:00
#
# RT @saranghaeshopi: KUMPULAN MEME TWEET
#
# — A THREAD https://t.co/WXmqsTTik6
# {'retweet_count': 6696, 'reply_count': 0, 'like_count': 0, 'quote_count': 0, 'impression_count': 0}
#
#
# Tweet ID: 1613549043833004032
# Created: 2023-01-12 14:50:44+00:00
#
# RT @julianalssart: 1 - a criança tá achando que é uma brincadeira bater a garrafa no cachorro, dá pra ver que ela fez a mesma coisa com uma…
# {'retweet_count': 16, 'reply_count': 0, 'like_count': 0, 'quote_count': 0, 'impression_count': 0}
#
#
# Tweet ID: 1613549043829059584
# Created: 2023-01-12 14:50:44+00:00
#
# RT @narendramodi: Institution और Innovation! इन दोनों को लेकर स्वामी विवेकानंद के संदेश को आज हर युवा को अपने जीवन का हिस्सा बनाना चाहिए। h…
# {'retweet_count': 320, 'reply_count': 0, 'like_count': 0, 'quote_count': 0, 'impression_count': 0}
#
#
# Tweet ID: 1613549043829051393
# Created: 2023-01-12 14:50:44+00:00
#
# RT @HELLO59982641: https://t.co/ZZR2OHKXRe
# {'retweet_count': 30, 'reply_count': 0, 'like_count': 0, 'quote_count': 0, 'impression_count': 0}
#
#
# Tweet ID: 1613549043829047297
# Created: 2023-01-12 14:50:44+00:00
#
# この動画好きすぎるんよな https://t.co/bIt7iYOru2
# {'retweet_count': 0, 'reply_count': 0, 'like_count': 0, 'quote_count': 0, 'impression_count': 0}

# %% [markdown]
# **Question**: Which Tweet (out of the ones returned) has been retweeted the most?

# %% [markdown]
# ## Exercise 10
# Write code below to search for recent Tweets that are from Elon Musk and are not retweets or replies and to ensure Tweets are returned containing their `id`, `text`, `created_at`, and `public_metrics` fields.

# %%
# (SOLUTION)
query = 'from:elonmusk -is:retweet -is:reply' 
fields = [
    'id',
    'text',
    'created_at',
    'public_metrics',
]
tweets = client.search_recent_tweets(query=query, max_results=10,tweet_fields=fields)
for tweet in tweets.data:
    print(f'Tweet ID: {tweet.id}')
    print(f'Created: {tweet.created_at}\n')
    print(tweet.text)
    print(tweet.public_metrics)
    print('\n')
# Out:
# Tweet ID: 1613537584231362561
# Created: 2023-01-12 14:05:12+00:00
#
# Starship launch attempt soon https://t.co/QBprVsAH7m
# {'retweet_count': 6564, 'reply_count': 4555, 'like_count': 67409, 'quote_count': 779, 'impression_count': 3123187}
#
#
# Tweet ID: 1613249758256328705
# Created: 2023-01-11 19:01:29+00:00
#
# Some things that your party tells you are false and some things that the other party says are true
# {'retweet_count': 22808, 'reply_count': 27219, 'like_count': 260681, 'quote_count': 3175, 'impression_count': 26518590}
#
#
# Tweet ID: 1612699840571637760
# Created: 2023-01-10 06:36:19+00:00
#
# All four orbital launch pads fully loaded with rockets for the first time! https://t.co/EXlB0p5vWN
# {'retweet_count': 7487, 'reply_count': 5964, 'like_count': 89182, 'quote_count': 493, 'impression_count': 18999259}
#
#
# Tweet ID: 1612230045493248001
# Created: 2023-01-08 23:29:31+00:00
#
# I hope that the people of Brazil are able to resolve matters peacefully
# {'retweet_count': 26025, 'reply_count': 36512, 'like_count': 398359, 'quote_count': 5626, 'impression_count': 58397287}
#
#
# Tweet ID: 1612213483625668608
# Created: 2023-01-08 22:23:42+00:00
#
# (Chart by James Stephenson) https://t.co/rOHfjXGVmU
# {'retweet_count': 8105, 'reply_count': 6540, 'like_count': 84440, 'quote_count': 843, 'impression_count': 21341053}
#
#
# Tweet ID: 1611932793130438656
# Created: 2023-01-08 03:48:20+00:00
#
# Easy swipe right/left to move between recommended vs followed tweets rolls out later this week.
#
# First part of a much larger UI overhaul.
#
# Bookmark button (de facto silent like) on Tweet details rolls out a week later.
#
# Long form tweets early Feb.
# {'retweet_count': 13602, 'reply_count': 12399, 'like_count': 167427, 'quote_count': 2889, 'impression_count': 25303913}
#
#
# Tweet ID: 1611857881808375808
# Created: 2023-01-07 22:50:40+00:00
#
# Plaid is sickkk https://t.co/OxBD8Zv7Xq
# {'retweet_count': 5510, 'reply_count': 8240, 'like_count': 83214, 'quote_count': 562, 'impression_count': 26341426}
#
#
# Tweet ID: 1611768674653982720
# Created: 2023-01-07 16:56:11+00:00
#
# Thread on how safe Tesla cars are https://t.co/M3Hf3q4kh3
# {'retweet_count': 4845, 'reply_count': 5907, 'like_count': 51070, 'quote_count': 527, 'impression_count': 18453880}
#
#
# Tweet ID: 1611423667107549184
# Created: 2023-01-06 18:05:15+00:00
#
# 8 years later &amp; still no laws … 😢 https://t.co/9fjb24XvFG
# {'retweet_count': 31099, 'reply_count': 27043, 'like_count': 404330, 'quote_count': 3540, 'impression_count': 57763657}
#
#
# Tweet ID: 1611146457222086657
# Created: 2023-01-05 23:43:43+00:00
#
# If I dig my grave deep enough, maybe it comes out other side of Earth 🤔
# {'retweet_count': 21062, 'reply_count': 48149, 'like_count': 335562, 'quote_count': 4491, 'impression_count': 44023010}

# %% [markdown]
# **Question**: Which of Elon Musk's recent Tweets has been retweeted the most? Which has received the most likes?

# %% [markdown]
# # (Graph network stuff!!!)

# %%
user = client.get_user(id='elonmusk')
followers = client.get_users_followers(user.id)
print(followers)
# Out:
# ---------------------------------------------------------------------------
# BadRequest                                Traceback (most recent call last)
# /var/folders/mm/tcww8c050pz_ryvpkqkddsmh0000gn/T/ipykernel_83476/2757708908.py in <module>
# ----> 1 user = client.get_user(id='elonmusk')
#       2 followers = client.get_users_followers(user.id)
#       3 print(followers)
#
# ~/Bristol/Github/social-media-mining/.env/lib/python3.7/site-packages/tweepy/client.py in get_user(self, id, username, user_auth, **params)
#    2442             "GET", route, params=params,
#    2443             endpoint_parameters=("expansions", "tweet.fields", "user.fields"),
# -> 2444             data_type=User, user_auth=user_auth
#    2445         )
#    2446
#
# ~/Bristol/Github/social-media-mining/.env/lib/python3.7/site-packages/tweepy/client.py in _make_request(self, method, route, params, endpoint_parameters, json, data_type, user_auth)
#     128
#     129         response = self.request(method, route, params=request_params,
# --> 130                                 json=json, user_auth=user_auth)
#     131
#     132         if self.return_type is requests.Response:
#
# ~/Bristol/Github/social-media-mining/.env/lib/python3.7/site-packages/tweepy/client.py in request(self, method, route, params, json, user_auth)
#      94
#      95             if response.status_code == 400:
# ---> 96                 raise BadRequest(response)
#      97             if response.status_code == 401:
#      98                 raise Unauthorized(response)
#
# BadRequest: 400 Bad Request
# The `id` query parameter value [elonmusk] is not valid
